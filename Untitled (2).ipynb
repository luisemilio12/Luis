# %% [markdown]
# # Clase 1 : Pasos basicos

# %%
print('hola')
# Out:
# hola

# %%
# %ls

# %%
Nombre= 'my name'
Nombre
# Out:
# 'my name'

# %%
import numpy as np

# %%
N=50
x=np.random.rand(N)
x
# Out:
# array([0.73103129, 0.16050164, 0.57353894, 0.0592409 , 0.00314812,
#        0.50863554, 0.04202149, 0.65640418, 0.71144797, 0.67206492,
#        0.93455969, 0.6162047 , 0.8342893 , 0.97471685, 0.73833264,
#        0.41890172, 0.53642596, 0.60240558, 0.40002233, 0.99844773,
#        0.39105466, 0.92358372, 0.76269659, 0.47644092, 0.40903039,
#        0.94517619, 0.727711  , 0.28398844, 0.98760855, 0.70486182,
#        0.55569847, 0.78145021, 0.03877725, 0.68297907, 0.38430003,
#        0.04839525, 0.59954912, 0.00353721, 0.19553443, 0.51332825,
#        0.29638741, 0.90516227, 0.6507665 , 0.63145195, 0.13292079,
#        0.74761277, 0.41809471, 0.82869116, 0.10777385, 0.73652651])

# %% [markdown]
# # Typos de data

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(pi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_143/2288253938.py in <module>
# ----> 1 type(pi)
#
# NameError: name 'pi' is not defined

# %%
math.pi
# Out:
# 3.141592653589793

# %%
type(Nombre)
# Out:
# str

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
type(True)
# Out:
# bool

# %%
type(2/3)
# Out:
# float

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
sum(numbers)
# Out:
# 15

# %%
length_numbers = len(numbers)
length_numbers
# Out:
# 5

# %%
60*10**-2
# Out:
# 0.6

# %%
type(bool('yes'))
# Out:
# bool

# %%
type(6<5)
# Out:
# bool

# %%
a_list = [True, 6<5, 1==3, None is None, 'Name']
a_list
# Out:
# [True, False, False, True, 'Name']

# %%
x=10
y=6
if x<y:
    print('{} es menor que {}'.format(x,y))
else:
    print('{} es mayor que {}'.format(x,y))
# Out:
# 10 es mayor que 6
