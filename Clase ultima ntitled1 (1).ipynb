# %% [markdown]
# # 'plottly basicos'

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns; sns.set() 
import matplotlib as mpl
import matplotlib.pyplot as plt 
import statsmodels.api as sm 
from sklearn import linear_model
#import statsmodels.formula.api as smf

# %%
import plotly.express as px 
import plotly.graph_objects as go

# %%
# %ls datasets
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           cwurData.csv   pokemon.csv
# antropometria00.csv        data.csv       sample_pivot.csv
# antropometria-dataset.csv  headbrain.csv  tips.csv
# Canada.xlsx                mic.xlsx       weight-height.csv
# Cartwheeldata.csv          movies.csv

# %%
df = pd.read_csv('datasets/airline_data.csv',
               low_memory = False)
df.head()
# Out:
#    Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0     1295781  1998        2      4           2          4  1998-04-02
# 1     1125375  2013        2      5          13          1  2013-05-13
# 2      118824  1993        3      9          25          6  1993-09-25
# 3      634825  1994        4     11          12          6  1994-11-12
# 4     1888125  2017        3      8          17          4  2017-08-17
#
#   Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                AS                     19930                          AS
# 1                EV                     20366                          EV
# 2                UA                     19977                          UA
# 3                HP                     19991                          HP
# 4                UA                     19977                          UA
#
#    ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# ...

# %%
data = df.sample(n = 500,
                random_state = 42)
data.shape
# Out:
# (500, 110)

# %% [markdown]
# * price - jajajajjajaja

# %%
fig = go.Figure(data = go.Scatter(x = data['Distance'],
                                  y = data['DepTime'],
                                  mode = 'markers',
                                  marker = dict(color = 'red')
                                 )
               )
fig.show()

##deberia de graficar dispersion
# Out:
# <div>                            <div id="0989cfe4-728e-4f66-b7b0-bdfcb1fff7c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0989cfe4-728e-4f66-b7b0-bdfcb1fff7c9")) {                    Plotly.newPlot(                        "0989cfe4-728e-4f66-b7b0-bdfcb1fff7c9",                        [{"marker":{"color":"red"},"mode":"markers","type":"scatter","x":[946.0,1846.0,326.0,255.0,316.0,414.0,1554.0,629.0,1095.0,332.0,1189.0,392.0,137.0,332.0,733.0,423.0,1726.0,2296.0,1046.0,984.0,1569.0,743.0,236.0,595.0,2158.0,842.0,1440.0,223.0,1303.0,347.0,1005.0,1028.0,2585.0,1503.0,408.0,580.0,606.0,196.0,256.0,410.0,1303.0,677.0,715.0,1235.0,849.0,637.0,408.0,1449.0,599.0,2615.0,1726.0,120.0,453.0,113.0,156.0,155.0,228.0,2378.0,1147.0,756.0,177.0,502.0,316.0,16
# ...

# %%
print("kk")
# Out:
# kk

# %%
print("kk")
# Out:
# kk

# %%
print("kk")
# Out:
# kk

# %%
fi

# %%
bar_data = data.groupby (['DestState'])['Flights'].sum().reset_index()
bar_data.head()
# Out:
#   DestState  Flights
# 0        AK      1.0
# 1        AL      1.0
# 2        AR      3.0
# 3        AZ     11.0
# 4        CA     67.0

# %%
fig = px.bar(bar_data, 
             x = 'DestState',
             y = 'Flights')
fig.show()
## grafica de barras
# Out:
# <div>                            <div id="d4d0dd92-5c57-4461-a05e-99ce813b0c80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4d0dd92-5c57-4461-a05e-99ce813b0c80")) {                    Plotly.newPlot(                        "d4d0dd92-5c57-4461-a05e-99ce813b0c80",                        [{"alignmentgroup":"True","hovertemplate":"DestState=%{x}<br>Flights=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["AK","AL","AR","AZ","CA","CO","CT","FL","GA","HI","IA","ID","IL","IN","KY","LA","MA","MD","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","PR","RI","SC","TN","TX","UT",
# ...

# %%
pip install dash
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter_dash
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=b472eb05fe1a189cacaa3e0a72faf974aa9cb3568b39abf051b26b340fadab8e
#   Stored in directory: /home/jovyan/.cache/pip/wheels/c4/a7/48/0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash 
import dash_html_components as html
import dash_core_components as dcc
from jupyter_dash import JupyterDash

# %%
app = JupyterDash(__name__)
app.layout = html.Div(children = [html.H1('Airline Dashborard',
                                          style = {}
                                         ),
                      html.P('titulo'),
                      doc.Graph(figure = fig)
                      ]
                     )
if__name__ == '__main__':
    app.run_server()
# Out:
#   File "/tmp/ipykernel_174/3513038564.py", line 9
#     if__name__ == '__main__':
#                              ^
# SyntaxError: invalid syntax
